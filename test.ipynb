# %%
from tools.image import get_image, get_blank_image, alpha_rotate, set_opacity_inplace, image_fitness_pixel_by_pixel, compare_images
from config import *
from individual import Individual
from genetic import Genetic
from constants import WHITE, BLACK
import time
import numpy as np
import logging
from PIL import ImageDraw, Image
from tools.timer import MeasureTime


logging.basicConfig(level=logging.INFO)

# %%
target_image = get_image('images/smile.png', SIZE)

g = Genetic(target_image)
# Out:
# INFO:root:Code block 'creating population' took: 2587.906399006897 ms

# %%
target_image = get_image(TARGET_IMAGE, SIZE)
with MeasureTime():
  ind = Individual(target_image)
# Out:
# INFO:root:Code block took: 166.11984200426377 ms

# %%
mx, mn = max(g.population), min(g.population)

# %%
# Out:
# <PIL.Image.Image image mode=RGBA size=16x16 at 0x7F092B99F2B0>

# %%
g.run()
# Out:
# WARNING:root:#0. best is 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a4e638c88413> in <module>
# ----> 1 g.run()
#
# ~/innopolis/year02-semester02/AI/genetic-art/genetic.py in run(self)
#      47         except KeyboardInterrupt as e:
#      48             self.best.save('output')
# ---> 49             raise e
#      50
#      51     def evaluate(self):
#
# ~/innopolis/year02-semester02/AI/genetic-art/genetic.py in run(self)
#      33                     best.img.show()
#      34
# ---> 35                 self.evaluate()
#      36                 self.population.sort(reverse=True)
#      37
#
# ~/innopolis/year02-semester02/AI/genetic-art/genetic.py in evaluate(self)
#      55         with MeasureTime('evaluate'):
#      56             for individual in self.population:
# ---> 57                 individual.fitness()
#      58
# ...

# %%
Individual.load(None).img
# Out:
# WARNING:root:File is None. Load from output/genetic-27_18_38_15.pickle
# <PIL.Image.Image image mode=RGBA size=512x512 at 0x7F2EB815CF70>

# %%
# Out:
# INFO:root:Code block 'creating population' took: 1315.313311000864 ms

# %%
g.run()
# Out:
# INFO:root:Code block 'evaluate' took: 430.65770599969255 ms
# INFO:root:Code block 'crossover' took: 18.9823319997231 ms
# INFO:root:Code block 'select' took: 4.664268999476917 ms
# INFO:root:Code block 'mutation' took: 38.03290100040613 ms
# INFO:root:Code block 'evaluate' took: 269.65726200069184 ms
# INFO:root:Code block 'crossover' took: 29.751533000307973 ms
# INFO:root:Code block 'select' took: 3.1544140001642518 ms
# INFO:root:Code block 'mutation' took: 33.482225000625476 ms
# INFO:root:Code block 'evaluate' took: 290.5026340013137 ms
# INFO:root:Code block 'crossover' took: 106.04228800002602 ms
# INFO:root:Code block 'select' took: 4.151675000684918 ms
# INFO:root:Code block 'mutation' took: 55.517378999866196 ms
# INFO:root:Code block 'evaluate' took: 323.619487000542 ms
# INFO:root:Code block 'crossover' took: 23.97040100004233 ms
# INFO:root:Code block 'select' took: 3.7548370000877185 ms
# INFO:root:Code block 'mutation' took: 39.07304300082615 ms
# ...

# %%
ind = Individual.load('output/genetic-27_16_07_12.pickle')

# %%
ind.img
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512 at 0x7F67F33DDC70>

# %%
len(g.population)
# Out:
# 15

# %%
index = -1
kek.data[index].rotation = 0
kek.data[index].x = 0
kek.data[index].y = 0
kek.data[index].scale = 1
kek.data[index].opacity = 1
kek.data[index].update()
kek.relevant_image = False
kek.img
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512 at 0x7F72911BFF40>

# %%
cat = get_image('images/cat.jpg')
small_cat = cat.resize((SIZE[0] //2, SIZE[1] // 2))

# %%
x, y = 256, 512
N = 10
canvas = get_blank_image(SIZE)

img = get_image(c.source)

c.scale = 1/10

set_opacity_inplace(img, c.opacity)
img = scale(img, c.scale)
img = alpha_rotate(img, c.rotation)
W, H = img.size
x, y = x - W // 2, y - H // 2
canvas.paste(img, (x, y))
canvas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7fe0f2278415> in <module>
#       3 canvas = get_blank_image(SIZE)
#       4
# ----> 5 img = get_image(c.source)
#       6
#       7 c.scale = 1/10
#
# NameError: name 'c' is not defined

# %%
from tools import random_emoji
emoji = [get_image(f'emoji/{random_emoji()}', ) for _ in range(5)]

# %%
blank = get_blank_image(SIZE)

blank.alpha_composite(emoji[0], (55, 55))

blank
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512 at 0x7FC7C837BC40>

# %%
blank2 = get_blank_image(SIZE)
blank2.paste(alpha_rotate(small_cat, 45), (0, 250))
blank2
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512 at 0x7FEA5CE95820>

# %%
Image.alpha_composite(blank2, blank)
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512 at 0x7FEA5CE95130>

# %%
a = list(range(1000000))
with MeasureTime():
    a.sort(reverse=False)
# Out:
# INFO:root:Code block took: 6.332795001071645 ms

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-2ed0d7de6146> in <module>
# ----> 1 a.sort()
#
# AttributeError: 'range' object has no attribute 'sort'
